# %%
#libaries
import encodings
from bs4 import BeautifulSoup
import os 
import pandas as pd
from bs4 import BeautifulSoup
import textwrap
files_path=[]
files_names=[]
names=[]
paras=[]
parts=[] #extracted paragraphs
name_parts=[] #company_names with date
avarage_dist=[]
yes_no_list=[]

path= r'all_files_befoe_extract' # path for the folder.
def depdelete(path): #to get all insider paths within a folder.
    for eachFile in os.listdir(path):
                def lisdir(dir):
                    if ".htm" in eachFile:
                        files_names.append(eachFile)
                    # print(eachFile)
                    # print(os.path.abspath(os.path.join(dir, eachFile)))
                    v=os.path.abspath(os.path.join(dir, eachFile))
                    if ".htm" in v:
                        files_path.append(v)
                lisdir(path)
depdelete(path)               

 
c=0
for file in files_path:
 try:      
        
        file =open(file, 'r', encoding='utf-8')


        soup=BeautifulSoup(file)
        
       
        
        
        # for table in soup.find_all("table"):
        #     table.extract()
        # lines=soup.get_text(separator="./n", strip=True).split('./n')  #cut whole html to lines usin(/n)
        
        soup=soup.get_text()
        lines=soup.splitlines()
        
        
       
                
        
        count__=len(soup.split()) #count all wors within html file
        count_half=count__/2      #half of all wors within html file
    
        
        found1="false1" #found1="false1" it is false until it found its phrase
        found2="false2"
        found3="false3"
        found4="false4"
        found5="false5"
        found5_2="false5_2"
        found6="false6"
        found7="false7"
        found8="false8"
        para1=[]  #it coloect all line from found1 phrase until it find the stop phrase
        para2=[]
        para3=[]
        para4=[]
        para5=[]
        para5_2=[]
        para6=[]
        para7=[]
        para8=[]
        para_line=[]  #it coloect all lines from beganing and i use the length of it to determine if it is not in the table of content.
        count_para1=0 #it count the para1 which is from found1 untill stop1
        count_para2=0
        count_para3=0
        count_para4=0
        count_para5=0
        count_para5_2=0
        count_para6=0
        count_para7=0
        count_para8=0
        count_para=0
        count_line=0  #it count all words from beganing 
        to_collocet_line="true" #this is to turn on the collect line.
       
        found="n"  # the random start value for found="final"
        
        for line in lines:
            # print(line)
            # print("--------------------------------------------------------------")
            if to_collocet_line=="true":
                para_line.append(line)
            count=len(line.split())
            if count != 0 :
                    percent_1=(3/count)*100
                    percent_2=(2/count)*100
                    percent_3=(4/count)*100
                    percent_4=(3/count)*100
                    percent_5=(5/count)*100
                    percent_6=(9/count)*100
                    percent_7=(2/count)*100
                    line=line.lower()


                    if found1=="true1":

                                
                                para1.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found1= "stop1"




                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found1= "stop1"



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found1= "stop1"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found1= "stop1"



                                elif"summary compensation" in line and percent_2 >=66:
                                    found1= "stop1" 
                            


                    if found2=="true2":

                                
                                para2.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found2= "stop2"




                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found2= "stop2"



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found2= "stop2"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found2= "stop2"



                                elif"summary compensation" in line and percent_2 >=66:
                                    found2= "stop2"
                                
                            
                    if found3=="true3":

                                
                                para3.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found3= "stop3"




                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found3= "stop3"



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found3= "stop3"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found3= "stop3"



                                elif"summary compensation" in line and percent_2 >=66:
                                    found3= "stop3"
                              
                            
                   
                    if found4=="true4":

                               
                                para4.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found4= "stop4"




                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found4= "stop4"



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found4= "stop4"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found4= "stop4"



                                elif"summary compensation" in line and percent_2 >=66:
                                    found4= "stop4"
                            
                    if found5=="true5":

                                
                                para5.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found5= "stop5"




                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found5= "stop5"
                                    # paragraph=" ".join(para5)
                                    # count_para=len(paragraph.split())
                                    # print(count_para)
                                    # if count_para <50:
                                    #     found5="false5"
                                    #     para5=[]



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found5= "stop5"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found5= "stop5"




                                elif"summary compensation" in line and percent_2 >=66:
                                    found5= "stop5"  
                    if found5_2=="true5_2":

                                
                                para5_2.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found5_2= "stop5_2"




                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found5_2= "stop5_2"
                                    # paragraph=" ".join(para5)
                                    # count_para=len(paragraph.split())
                                    # print(count_para)
                                    # if count_para <50:
                                    #     found5="false5"
                                    #     para5=[]



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found5_2= "stop5_2"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found5_2= "stop5_2"




                                elif"summary compensation" in line and percent_2 >=66:
                                    found5_2= "stop5_2"          
                    if found6=="true6":

                                
                                para6.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found6= "stop6"





                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found6= "stop6"



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found6= "stop6"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found6= "stop6"



                                elif"summary compensation" in line and percent_2 >=66:
                                    found6= "stop6" 
                            
                    if found7=="true7":

                                
                                para7.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found7= "stop7"





                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found7= "stop7"



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found7= "stop7"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found7= "stop7"



                                elif"summary compensation" in line and percent_2 >=66:
                                    found7= "stop7" 
                            
                    if found8=="true8":

                                
                                para8.append(line)

                                if "summary compensation table" in line and percent_1 >=75:
                                    found8= "stop8"





                                elif "summary compensation tables" in line and percent_1 >=75:
                                    found8= "stop8"



#                                 elif "summary compensation table" in line and percent_1 >=50:
#                                     found8= "stop8"



#                                 elif "summary compensation tables" in line and percent_1 >=50:
#                                     found8= "stop8"



                                elif"summary compensation" in line and percent_2 >=66:
                                    found8= "stop8"  
                            
                   
                   




                    para_line_collect=" ".join(para_line)
                    count_line=len(para_line_collect.split())
                    
                    
                    if (found1== "false1" or found2== "false2" or found3== "false3" or found4== "false4" or found5== "false5" or found5_2== "false5_2" or found6== "false6" or found8== "false8" or found7== "false7") and count_line >=2000:

                        to_collocet_line="false" #this to stop collecting line becuase we do not need it after it reach 200 words.
                        if "COMPENSATION COMMITTEE REPORT".lower() in line and percent_4>=75:
                                paragraph=" ".join(para1) #this is used if it find "COMPENSATION COMMITTEE REPORT" for the second time
                                count_para=len(paragraph.split())
                                if count_para <=50:
                                    found1="true1" 
                                    para1=[]


                        if "REPORT OF THE COMPENSATION COMMITTEE".lower() in line and percent_5>=80:
                                    paragraph=" ".join(para2)
                                    count_para=len(paragraph.split())
                                    if count_para <=50:
                                        found2="true2"
                                        para2=[]


                        if "REPORT OF THE BOARD OF DIRECTORS ON EXECUTIVE COMPENSATION".lower() in line and percent_6>=90:
                                       paragraph=" ".join(para3)
                                       count_para=len(paragraph.split())
                                       if count_para <=50:
                                            found3="true3"
                                            para3=[]


                        if "EXECUTIVE COMPENSATION".lower() in line and percent_7>=66: 
                                paragraph=" ".join(para4)
                                count_para=len(paragraph.split())
                                if count_para <=50:
                                    found4="true4"
                                    para4=[]
                                    


                        if"compensation discussion and analysis".lower() in line :
                                paragraph=" ".join(para5)
                                count_para=len(paragraph.split())
                                if count_para <=50:
                                    found5="true5" 
                                    para5=[]
                       
                        if"compensation discussion and analysis".lower() in line and percent_3>=80 :
                                paragraph=" ".join(para5_2)
                                count_para=len(paragraph.split())
                                if count_para <=50:
                                    found5_2="true5_2" 
                                    para5_2=[]


                        # if "COMPENSATION COMMITTEE REPORT".lower() in line and percent_4>=50:
                        #         paragraph=" ".join(para6)
                        #         count_para=len(paragraph.split())
                        #         if count_para <=50:
                        #             found6="true6" 
                        #             para6=[]


                        # if "REPORT OF THE COMPENSATION COMMITTEE".lower() in line and percent_5>=50:
                        #         paragraph=" ".join(para7)
                        #         count_para=len(paragraph.split())
                        #         if count_para <=50:
                        #             found7="true7" 
                        #             para7=[]


                        # if "REPORT OF THE BOARD OF DIRECTORS ON EXECUTIVE COMPENSATION".lower() in line and percent_6>=50:
                        #         paragraph=" ".join(para8)
                        #         count_para=len(paragraph.split())
                        #         if count_para <=50:
                        #             found8="true8" 
                        #             para8=[]



        paragraph1=" ".join(para1)
        count_para1=len(paragraph1.split())
        
        paragraph2=" ".join(para2)
        count_para2=len(paragraph2.split()) 
       
        paragraph3=" ".join(para3)
        count_para3=len(paragraph3.split())
        
        paragraph4=" ".join(para4)
        count_para4=len(paragraph4.split())
        
        paragraph5=" ".join(para5)
        count_para5=len(paragraph5.split())
        
        paragraph5_2=" ".join(para5_2)
        count_para5_2=len(paragraph5_2.split())
        
        paragraph6=" ".join(para6)
        count_para6=len(paragraph6.split())
        
        paragraph7=" ".join(para7)
        count_para7=len(paragraph7.split())
        
        paragraph8=" ".join(para8)
        count_para8=len(paragraph8.split())  
        
        

        if found1!="stop1":
            count_para1=0
        if found2!="stop2":
            count_para2=0    
        if found3!="stop3":
            count_para3=0
        if found4!="stop4":
            count_para4=0
        if found5!="stop5":
            count_para5=0
        if found5_2!="stop5_2":
            count_para5_2=0    
        if found6!="stop6":
            count_para6=0 
        if found7!="stop7":
            count_para7=0 
        if found8!="stop8":
            count_para8=0    
        if count_para1 < count_half and count_para1 >200 and count_para1 >=  count_para2 and count_para1 >= count_para3 and count_para1 >= count_para4 and count_para1 >= count_para5 and count_para1 >= count_para6 and count_para1 >= count_para7 and count_para1 >= count_para8:
            found="final" 
            para=para1
            count_para=count_para1
        if count_para2 < count_half and count_para2 >200 and count_para2 >=  count_para1 and count_para2 >= count_para3 and count_para2 >=  count_para4 and count_para2 >=  count_para5 and count_para2 >=  count_para6 and count_para2 >=  count_para7 and count_para2 >=  count_para8:
            found="final"
            count_para=count_para2
            para=para2
        if count_para3 < count_half and count_para3 >200 and count_para3 >=  count_para2 and count_para3 >= count_para1 and count_para3 >= count_para4 and count_para3 >= count_para5 and count_para3 >= count_para6 and count_para3 >= count_para7 and count_para3 >= count_para8:
            found="final" 
            para=para3
            count_para=count_para3
        if  count_para4 < count_half and count_para4 >200 and count_para4 >=  count_para2 and count_para4 >= count_para3 and count_para4 >= count_para1 and count_para4 >= count_para5 and count_para4 >= count_para6 and count_para4 >= count_para7 and count_para4 >= count_para8:
            found="final"
            para=para4
            count_para=count_para4
        if  count_para5 < count_half and count_para5 >200 and count_para5 >=  count_para2 and count_para5 >=  count_para3 and count_para5 >=  count_para4 and count_para5 >=  count_para1 and count_para5 >=  count_para6 and count_para5 >=  count_para7 and count_para5 >=  count_para8:
            found="final"
            para=para5
            count_para=count_para5
        if  count_para6 < count_half and count_para6 >200 and count_para6 >=  count_para2 and count_para6 >=  count_para3 and count_para6 >=  count_para4 and count_para6 >=  count_para5 and count_para6 >=  count_para1 and count_para6 >=  count_para7 and count_para6 >=  count_para8:
            found="final" 
            para=para6
            count_para=count_para6
        if count_para7 < count_half and count_para7 >200 and count_para7 >=  count_para2 and count_para7 >= count_para3 and count_para7 >= count_para4 and count_para7 >= count_para5 and count_para7 >= count_para6 and count_para7 >= count_para1 and count_para7 >= count_para8:
            found="final"
            para=para7
            count_para=count_para7
        if count_para8 < count_half and count_para8 >200 and count_para8 >=  count_para2 and  count_para8 >= count_para3 and  count_para8 >= count_para4 and  count_para8 >= count_para5 and  count_para8 >= count_para6 and  count_para8 >= count_para7 and  count_para8 >= count_para1:
            found="final" 
            para=para8
            count_para=count_para8
           
        
        if found5=="stop5" and count_para5 < count_half and count_para5 >200:
            count_para=count_para5
            
            paragraph=" ".join(para5)
 
            parts.append(paragraph)
                
            name_parts.append(files_names[c])
            yes_no_list.append("yes_1")
            
        elif found5_2=="stop5_2" and count_para5_2 < count_half and count_para5_2 >200:
            count_para=count_para5_2
            
            paragraph=" ".join(para5_2)
 
            parts.append(paragraph)
                
            name_parts.append(files_names[c])
            yes_no_list.append("yes_2")

        elif found=="final" : 
                
            paragraph=" ".join(para)
     
            parts.append(paragraph)
      
            name_parts.append(files_names[c])
            yes_no_list.append("no")
            

        
            
               
          
 except:
        print("not working")
 c=c+1   

dict={'companyName': name_parts, 'paragraph':parts, "yes/no":yes_no_list}
df=pd.DataFrame(dict)
df.to_csv("extracted_results.csv")


# dict={'paragraph': parts}
# df=pd.DataFrame(dict)
# df.to_stata("results_paras.dta")   


print("done done")
